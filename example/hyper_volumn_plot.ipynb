# %%
import os
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd
import joblib

# %%
# 讀取資料
pkl_dir = '/workspaces/BO_EXPERIMENTS/src/results/20260204/mobo_lasso_generater/pkl/qnlhevi'
pkl_path_ls = [os.path.join(pkl_dir, n) for n in os.listdir(pkl_dir)]

hv_data_ls = []
for pkl_path in pkl_path_ls:
    data_info = joblib.load(pkl_path)
    hv_data_ls.append(data_info)

# %%
hv_data_ls[0].keys()
# Out:
# dict_keys(['hv_ls', 'datasplit_seed'])

# %%
# 根據存檔的超體積資訊繪圖
plt.figure(figsize=(10, 5))
for hv_data in hv_data_ls:
    hv_
plt.plot(current_hvs, marker='o', linestyle='-', color='b', label='Hyper V')

# 加入標題與標籤
plt.title('MOBO Hyper Volume')
plt.xlabel('Iter')
plt.ylabel('Volume')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# 4. 顯示圖表
plt.show()
